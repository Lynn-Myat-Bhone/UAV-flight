# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv("../data/uav_fault_dataset.csv")
raw_data.shape

# %%
raw_data.columns
# Out:
# Index(['bag', 'timestamp_ns', 'airspeed_cmd', 'airspeed_meas',
#        'airspeed_error', 'roll_cmd', 'roll_meas', 'roll_error', 'pitch_cmd',
#        'pitch_meas', 'pitch_error', 'yaw_cmd', 'yaw_meas', 'yaw_error',
#        'vel_x', 'vel_y', 'vel_z', 'imu_roll', 'imu_pitch', 'imu_yaw',
#        'battery_voltage', 'battery_current', 'battery_percent', 'engine_fault',
#        'aileron_fault', 'elevator_fault', 'rudder_fault'],
#       dtype='object')

# %%
raw_data.head(3)
# Out:
#                                bag  timestamp_ns  airspeed_cmd  airspeed_meas  \
# 0  carbonZ_2018-07-18-12-10-11.bag             0           NaN            NaN
# 1  carbonZ_2018-07-18-12-10-11.bag      50000000           NaN            NaN
# 2  carbonZ_2018-07-18-12-10-11.bag     100000000           NaN            NaN
#
#    airspeed_error  roll_cmd  roll_meas  roll_error  pitch_cmd  pitch_meas  \
# 0             NaN       NaN        NaN         NaN        NaN         NaN
# 1             NaN       NaN        NaN         NaN        NaN         NaN
# 2             NaN       NaN        NaN         NaN        NaN         NaN
#
#    ...  imu_roll  imu_pitch   imu_yaw  battery_voltage  battery_current  \
# 0  ...       NaN        NaN       NaN              NaN              NaN
# 1  ... -0.015858  -0.004912 -0.988456              0.0             0.01
# 2  ... -0.015858  -0.004912 -0.988456              0.0             0.01
#
# ...
